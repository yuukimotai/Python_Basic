# %%
# %matplotlib inline
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

img = Image.open('./janken/img/gu.png')
plt.imshow(img)

# %%
gu_array = np.array(img)
gu_array.shape
# Out:
# (220, 220, 4)

# %%
gu_array[100][100]
# Out:
# array([245, 167,  95, 255], dtype=uint8)

# %%
plt.plot([100, 100],[175, 100], 'r')
plt.plot([100, 160],[100, 100], 'r')
plt.plot([160, 160],[175, 100], 'r')
plt.plot([160, 100],[175, 175], 'r')
plt.imshow(img)

# %%
plt.plot([100, 100],[175, 100], 'go-')
plt.plot([100, 160],[100, 100], 'go-')
plt.plot([160, 160],[175, 100], 'gx-')
plt.plot([160, 100],[175, 175], 'gx-')
plt.imshow(img)

# %%
plt.plot([1,2,3,4],[2,4,6,8])
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
x = np.arange(1, 20, 1)
y1 = 2 * x
y2 = x ** 2
y3 = x ** 3
plt.plot(x, y1,'go-', label='y1')# bar: 棒グラフ, scatter: 散布図, plot: 折れ線グラフ
plt.plot(x, y2, 'ko-', label='y2')
plt.plot(x, y3, 'b*--', label='y3')
plt.legend()
plt.show()
